# %%
import urllib.request
import requests
from urllib.request import Request,urlopen
from bs4 import BeautifulSoup
import json
base_url='https://www.ndtv.com/business?pfrom=home-header-globalnav'

d={
    'url':base_url,
    'article':[{
        
    }]
}


r=Request(base_url,headers={'User-Agent':'Mozilla/5.0'})
open_base=urllib.request.urlopen(r)
data_base=BeautifulSoup(open_base,"html.parser")

all_headlines=data_base.find_all('a',attrs={"item-title"})
count=0

for link in all_headlines:
    articleDICT={}
    
    
    articleDICT['Category']='Economy'
    
    
    articleDICT['ID']='NDTV Profit'
    
    
    url = link.get('href')
    articleDICT['url']=url
    
    
    r=Request(url,headers={'User-Agent':'Mozilla/5.0'})
    open_=urllib.request.urlopen(r)
    data=BeautifulSoup(open_,"html.parser")
    
    
    h_data=data.find_all('h1')
    title=""
    for i in range(0,len(h_data)):
        title=h_data[i].get_text()   
    articleDICT['TITLE:']=title
    
    
    
    date_data = data.find('div',attrs={"ins_dateline"})
    #articleDICT['Date']=date_data.get_text()
    #f.write('\n\n'+"Category | Writer | Date&Time:-'\n' "+date_data.get_text()+ '\n\n\n\n')
    
    
    p_data=data.find_all('p')
    para=""
    for i in range(0,len(p_data)):
        para=para+p_data[i].get_text()   #doubt
    articleDICT['content']=para
    
    
    related_urls=data.find('ul').find_all('li')
    relatedURLs=""
    for i in range(0,len(related_urls)):
        relatedURLs=relatedURLs+str(related_urls[i])
        #relatedURLs.append(str(related_urls[i]))
    articleDICT['Links']=relatedURLs
    
    
    
    images=data.find_all('img')
    imageURLs=""
    for i in images:
        imageURLs=imageURLs+i['src']
    articleDICT['imageURls']=imageURLs
    
    
    
    caption=""
    for i in range(0,len(h_data)):
        caption=caption+h_data[i].get_text()
    articleDICT['imageCAPTIONS']=caption
    
    
    d['article'].append(articleDICT)
    
with open('f_articleJSON.json','w') as e:
    json.dump(d,e,indent=2)
    
f_articleJSON=json.dumps(d)
print(f_articleJSON)
# Out:
# {"url": "https://www.ndtv.com/business?pfrom=home-header-globalnav", "article": [{}, {"Category": "Economy", "ID": "NDTV Profit", "url": "https://www.ndtv.com/business/bse-sensex-today-live-market-update-nifty-likely-to-open-flat-axis-bank-infosys-shares-in-focus-2121147", "TITLE:": "Sensex Jumps Over 200 Points, Nifty Hits 11,650: LIVE Market Updates", "content": "Gains across most sectors - led by banking, IT and auto shares - pushed the markets higherDomestic stock markets continued their upmove on Wednesday after a day's pause amid volatile trade. The S&P BSE Sensex index gained as much as\u00a0223.61 points to touch 39,187.45 on the upside and the broader NSE Nifty benchmark climbed to as high as 11,651.60, up 63.25 points from its previous close. Gains across most sectors - led by banking, information technology and automobile shares - pushed the markets higher.\u00a0On Tuesday, the Sensex had ended 334.54 points - or 0.85 per cent - lower at 38,963.84 and the Nifty settled at 11,588